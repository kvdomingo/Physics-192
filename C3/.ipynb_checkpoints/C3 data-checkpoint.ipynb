# %%
import numpy as np
import matplotlib.pyplot as mp
import matplotlib.ticker as tick
import scipy.stats as stat
from jupyterthemes import jtplot

# %%
jtplot.reset()
mp.style.use("seaborn")
mp.rcParams["font.family"] = "serif"
mp.rcParams["text.usetex"] = True
mp.rcParams["figure.figsize"] = (5*16/9, 5)
mp.rcParams["figure.dpi"] = 100

# %%
Ts = 24 + 273.15
V1 = 1.8

# %%
Vps, Vmm, I = np.genfromtxt("C3dat.txt", skip_header=1).T
R = Vmm/I
P = Vmm*I
P1 = P[8]
R1 = R[8]

# %%
mp.plot(I, R, "o")
mp.xlabel("current (A)")
mp.ylabel(r"resistance ($\Omega$)")
mp.show()

# %%
x = 4*np.log(R/R1)
y = np.log(P/P1)
m, b, r, p, sd = stat.linregress(x, y)

mp.plot(x, y, "o", label="data")
mp.plot(x, m*x + b, label="$m = %.2f$, $b = %.2f$, $R^2 = %.2f$"%(m, b, r**2))
mp.xlabel("$4\log(R/R_1)$")
mp.ylabel("$\log(P/P_1)$")
mp.legend()
mp.show()

# %%
T = Ts * (R/R1)**m

# %%
mp.plot(T, R, "o")
mp.ylabel(r"resistance ($\Omega$)")
mp.xlabel("temperature (K)")
mp.show()
